# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from datetime import datetime

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
dateParse = lambda dates: datetime.strptime(dates, "%Y-%m")
data = pd.read_csv("AirPassengers.csv", parse_dates=["Month"], index_col="Month", date_parser=dateParse)
data.head()
# Out:
# C:\Users\amrro\AppData\Local\Temp\ipykernel_7552\2992707543.py:2: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv("AirPassengers.csv", parse_dates=["Month"], index_col="Month", date_parser=dateParse)
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
ts = data["#Passengers"]
decompose = seasonal_decompose(ts)

# %%
plt.figure(figsize=(10, 8))

plt.subplot(3, 1, 1)
plt.plot(decompose.trend, color='blue', linestyle='-')
plt.title("Trend")
plt.xlabel("Time")
plt.ylabel("Value")

plt.subplot(3, 1, 2)
plt.plot(decompose.seasonal, color='green', linestyle='--')
plt.title("Seasonal")
plt.xlabel("Time")
plt.ylabel("Value")

plt.subplot(3, 1, 3)
plt.plot(decompose.resid, color='red', linestyle=':')
plt.title("Residual")
plt.xlabel("Time")
plt.ylabel("Value")

plt.tight_layout()
plt.show()
